# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
data = np.loadtxt('res.txt', delimiter = ',')

# %%
def plot(data):
    mpl.style.use('seaborn')
    
    labels = ['randomized select', 'deterministic select']

    fig, ax = plt.subplots(ncols = 1,figsize=(21,6))
    
    ax.set_ylabel('runtime (ms)')
    ax.set_xlabel('array input size')
    for j in range(2):
        ax.plot(data[:,1], data[:,2+j],
                 marker = "o",
                 label = labels[j]
                )
    ax.legend()
#     plt.savefig(xlabel+'.png')

# %%
plot(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b56f6e81433d> in <module>
# ----> 1 plot(data)
#
# <ipython-input-9-2fed1dbeb5ce> in plot(data)
#      14                 )
#      15     ax.legend()
# ---> 16     plt.savefig(xlabel+'.png')
#
# NameError: name 'xlabel' is not defined
